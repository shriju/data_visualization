# %% [markdown]
# <a href="https://colab.research.google.com/github/shriju/data_visualization/blob/main/Matplotlib_task_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

plt.style.use('default')

# %% [markdown]
# ## `Problem 1 to 5`:
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.
#
# ### **`Problem-1:`** Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
# code here
df=pd.read_csv("https://tinyurl.com/2fe6vz4u")
df
# Out:
#      Unnamed: 0  Position      Country     City/Town  Year  PM2.5  \
# 0             0         1        India        Kanpur  2016    173
# 1             1         2        India     Faridabad  2016    172
# 2             2         3        India          Gaya  2016    149
# 3             3         4        India      Varanasi  2016    146
# 4             4         5        India         Patna  2016    144
# ..          ...       ...          ...           ...   ...    ...
# 495         495       496       Poland        Lublin  2016     27
# 496         496       497       Poland       Siedlce  2016     27
# 497         497       498       Poland     Trzebinia  2016     27
# 498         498       499  El Salvador  San Salvador  2016     27
# 499         499       500       Turkey         Sivas  2016     27
#
#     Temporal coverage  PM10 Temporal coverage.1  Database version (year)
# 0                >75%   319                 NaN                     2018
# 1                >75%   316                 NaN                     2018
# 2          50% -< 75%   275                 NaN                     2018
# 3                >75%   260                 NaN                     2018
# 4                >75%   266                 NaN                     2018
# ..                ...   ...                 ...                      ...
# 495              >75%    31                >75%                     2018
# 496              >75%    29                >75%                     2018
# 497              >75%    35                >75%                     2018
# 498        50% -< 75%    59                 NaN                     2018
# 499              >75%    56                >75%                     2018
#
# [500 rows x 10 columns]

# %%
iran=df.query('Country=="Iran"').groupby('Year')['PM2.5'].sum()

# %%
china=df.query('Country=="China"').groupby('Year')['PM2.5'].sum()

# %%
plt.plot(iran.index, iran.values, label='Iran', linestyle='dashed')
plt.plot(china.index, china.values, label= 'China', linestyle='dotted', color='red')
plt.title('Iran vs China PM2.5')
plt.xlabel('Year')
plt.ylabel('Sum of PM2.5')
plt.xticks(df['Year'].value_counts().index)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-2:`** Draw a histogram of the  column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
# code here
plt.hist(df['PM10'], density=True, bins=50, facecolor='green', alpha=0.7, label='PM10')
plt.xlabel('Bins')
plt.ylabel('Probability')
plt.title('Histogram of PM10')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-3:`** Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
# code here
chile_df=df.query('Country=="Chile"')
poland_df=df.query('Country=="Poland"')

# %%
plt.scatter(chile_df['PM2.5'], chile_df['PM10'], marker='+', color='red', label='Chile')
plt.scatter(poland_df['PM2.5'], poland_df['PM10'], marker='*', color='blue', label='Poland')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('Poland Vs Chile')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-4:`** Draw a pie chart of top 5 most frequent countries.

# %%
# code here
freq_series=df['Country'].value_counts().head()

# %%
plt.pie(freq_series, labels=freq_series.index, autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### **`Problem-5:`** Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
# code here
plt.bar(freq_series.index, freq_series)
plt.xlabel('Country')
plt.ylabel('Frequency Count')
plt.title('Count of 5 most frequent countries')
plt.show()

# %% [markdown]
# ##`Problem 6-10`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.
#
#
# ###`Problem-6`
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
# code here
df1=pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv')
df1
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df1['month_number'], df1['total_profit'], label='profit', color='b', marker='o', linestyle='dotted')
plt.xlabel('month')
plt.ylabel('profit')
plt.title('Month to Month Profit')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ###`Problem-7`
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
# code here
march=df1[df1['month_number']==3].iloc[:,1:7]

# %%
plt.pie(march, labels=march.columns, autopct='%0.1f%%', explode=[0,0,0.1,0,0,0],shadow=True)
plt.title("Sales in March")
plt.show()
#labels=labels,autopct='%0.1f%%'
#labels=df.columns, autopct='%.2f'
# Out:
# <ipython-input-15-06ada0b1238f>:1: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(march, labels=march.columns, autopct='%0.1f%%', explode=[0,0,0.1,0,0,0],shadow=True)

# %% [markdown]
# ###`Problem-8` Multiline Plot of all products sales.
# * Give different styes for each products
# * Add legend at top right

# %%
# code here
monthList  = df1['month_number'].tolist()

plt.plot(monthList, df1['facecream'],   label = 'Face cream', linestyle='dotted', marker='o', linewidth=3)
plt.plot(monthList, df1['toothpaste'], label = 'Tooth Paste', marker='o', linewidth=3)
plt.plot(monthList, df1['bathingsoap'], label = 'Bathing Soap', marker='o', linewidth=3)
plt.plot(monthList, df1['shampoo'], label = 'Shampoo', linestyle='dashdot', linewidth=3)
plt.plot(monthList, df1['moisturizer'], label = 'Moisturizer', marker='o', linewidth=3)
plt.plot(monthList, df1['facewash'],   label = 'Face Wash',  linestyle='dashed', linewidth=2)


plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper right')
plt.xticks(monthList)
plt.title('Sales data')
plt.show()

# %% [markdown]
# ###`Problem-9` Show Quarter wise Sales data for all products as multi Bar chart.

# %%
# code here
df1['date']=pd.to_datetime(['2020-{}-01'.format(month) for month in df1['month_number']])

# %%
df1
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit       date
# 0          1500        21100        211000 2020-01-01
# 1          1200        18330        183300 2020-02-01
# 2          1340        22470        224700 2020-03-01
# 3          1130        22270        222700 2020-04-01
# 4          1740        20960        209600 2020-05-01
# 5          1555        20140        201400 2020-06-01
# 6          1120        29550        295500 2020-07-01
# 7          1400        36140        361400 2020-08-01
# 8          1780        23400        234000 2020-09-01
# 9          1890        26670        266700 2020-10-01
# 10         2100        41280        412800 2020-11-01
# 11         1760        30020        300200 2020-12-01

# %%
df1['date'].dt.quarter
# Out:
# 0     1
# 1     1
# 2     1
# 3     2
# 4     2
# 5     2
# 6     3
# 7     3
# 8     3
# 9     4
# 10    4
# 11    4
# Name: date, dtype: int64

# %%
final_df=df1.groupby(df1['date'].dt.quarter).sum()

# %%
for col in final_df.columns[1:7]:
  print(col)
# Out:
# facecream
# facewash
# toothpaste
# bathingsoap
# shampoo
# moisturizer

# %%
i = -1
for col in final_df.columns[1:7]:
  plt.bar(final_df.index + i,final_df[col],width=0.15,label=col)
  i = i - 0.15

plt.xticks(final_df.index-1.4,final_df.index)
plt.xlabel('Product')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %% [markdown]
# ###`Problem-10` Plot Stacked Bar chart quarter wise for each product.

# %%
# code here
final_df
# Out:
#       month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# date
# 1                6       7270      4040       14850        24850     6850
# 2               15       9760      4425       15320        24120     5320
# 3               24      10220      4300       16740        27040     6740
# 4               33       7230      5750       23000        38000     6500
#
#       moisturizer  total_units  total_profit
# date
# 1            4040        61900        619000
# 2            4425        63370        633700
# 3            4300        89090        890900
# 4            5750        97970        979700

# %%
all_cols = []

for col in final_df.columns[1:7]:
  if len(all_cols) == 0:
    plt.bar(final_df.index,final_df[col],label=col)
  else:
    plt.bar(final_df.index,final_df[col],bottom=sum(all_cols),label=col)
  all_cols.append(final_df[col])
